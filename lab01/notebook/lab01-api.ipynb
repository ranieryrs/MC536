# %% [markdown]
# # Lab 1 - API de Acesso a Dados

# %% [markdown]
# # Tarefa 1
#
# Das fontes de dados disponíveis, tente encontrar fontes com formatos diferentes e importá-las via Python. Busque pelo menos dois formatos.

# %%
import requests
url = "https://animechan.vercel.app/api/random"
data = requests.get(url).content
print(data.decode("utf-8"))
# Out:
# {"anime":"Wolf's Rain","character":"Kiba","quote":"Why? Why do humans always look to the sky? Why do you try so hard to fly when you don't have any wings? We'll run on our own legs."}

# %%
import requests
url = "https://thatcopy.pw/catapi/rest/"
data = requests.get(url).content
print(data.decode("utf-8"))
# Out:
# {"id":28,"url":"https://i.thatcopy.pw/cat/QcluRVh.jpg","webpurl":"https://i.thatcopy.pw/cat-webp/QcluRVh.webp","x":81.99,"y":28.64}
